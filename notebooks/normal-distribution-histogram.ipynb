# %%
import matplotlib.pyplot as plt
import numpy

lots_of_data = numpy.random.normal(10.0, 3.0, 100_000)
lots_of_data2 = numpy.random.uniform(5.0, 1.0, 100_000)

plt.hist(lots_of_data, 100)
plt.show()

# Scatter Plot
x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()
